# %% [markdown]
# # Tiny synthetic experiment
# Demonstrates a research-shaped notebook for the SDLC assessor fixture suite.

# %%
import statistics

data = [1, 2, 3, 4, 5]
print('mean=', statistics.mean(data))
